# %%
import numpy as np


def get_online_strategy_signal(steps_per_cycle: int = 10) -> np.ndarray:

    n_cycles = 2
    steps = n_cycles * steps_per_cycle
    
    t = np.linspace(0, n_cycles, num=steps, endpoint=True)
        
    return t, signal


from matplotlib import pyplot as plt

VILOTILE_UPDATES = 10
STABLE_UPDATES = 100
SLOW_UPDATES = 1_000


fig, ax = plt.subplots(figsize=(12, 4))

t, v = get_online_strategy_signal(steps_per_cycle=VILOTILE_UPDATES)
ax.plot(t, v, label="vilotile")

t, v = get_online_strategy_signal(steps_per_cycle=STABLE_UPDATES)
ax.plot(t, v, label="stable")

t, v = get_online_strategy_signal(steps_per_cycle=SLOW_UPDATES)
ax.plot(t, v, label="slow")

ax.legend()

# %%
import numpy as np

np.allclose(np.array([0, 1, 2]), np.array([1, 2]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
# ----> 3 np.allclose(np.array([0, 1, 2]), np.array([1, 2]))
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/numeric.py:2329, in allclose(a, b, rtol, atol, equal_nan)
#    2243 @array_function_dispatch(_allclose_dispatcher)
#    2244 def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):
#    2245     """
#    2246     Returns True if two arrays are element-wise equal within a tolerance.
#    2247
#    (...)
#    2327
#    2328     """
# -> 2329     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2330     return builtins.bool(res)
#
# File ~/.local/lib/python3.10/site-packages/numpy/_core/numeric.py:2447, in isclose(a, b, rtol, atol, equal_nan)
#    2444     y = float(y)
#    2446 with errstate(invalid='ignore'):
# ...
